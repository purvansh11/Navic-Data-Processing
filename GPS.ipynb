# %%
from google.colab import drive
drive.mount('/content/drive/')


# !pip install georinex
import georinex as gr
import numpy as np
print("hello")
file_name="/content/drive/My Drive/ACRD00IND_R_20192600425_02H_GN.rnx"
data=gr.load(file_name)
print(data)

ds=data.to_array
print(ds)

ds=data.to_dataframe()
ds['Crs'].replace('', np.nan, inplace=True)

ds.dropna(subset=['Crs'], inplace=True)
print(ds)
ds.to_csv(r"/content/drive/My Drive/GPS.csv",index=True)
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).
# Requirement already satisfied: georinex in /usr/local/lib/python3.6/dist-packages (1.13.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.6/dist-packages (from georinex) (2.6.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from georinex) (1.17.5)
# Requirement already satisfied: xarray>=0.11 in /usr/local/lib/python3.6/dist-packages (from georinex) (0.14.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.6/dist-packages (from python-dateutil->georinex) (1.12.0)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.6/dist-packages (from xarray>=0.11->georinex) (0.25.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.24->xarray>=0.11->georinex) (2018.9)
# hello
# <xarray.Dataset>
# Dimensions:           (sv: 12, time: 4)
# Coordinates:
#   * sv                (sv) <U3 'G02' 'G05' 'G10' 'G12' ... 'G26' 'G29' 'G32'
#   * time              (time) datetime64[ns] 2019-09-17T05:59:44 ... 2019-09-17T08:00:00
# Data variables:
#     SVclockBias       (time, sv) float64 -0.0003068 nan ... 9.563e-05 9.563e-05
#     SVclockDrift      (time, sv) float64 -8.185e-12 nan ... -1.023e-11
#     SVclockDriftRate  (time, sv) float64 0.0 nan nan nan nan ... 0.0 nan 0.0 0.0
#     IODE              (time, sv) float64 31.0 nan nan nan ... nan 123.0 123.0
#     Crs               (time, sv) float64 58.0 nan nan nan ... nan -22.72 -22.72
#     DeltaN            (time, sv) float64 4.608e-09 nan ... 3.732e-09 3.732e-09
#     M0                (time, sv) float64 -1.886 nan nan nan ... nan 1.317 1.317
#     Cuc               (time, sv) float64 3.152e-06 nan ... -1.363e-06 -1.363e-06
#     Eccentricity      (time, sv) float64 0.01913 nan nan ... 0.001185 0.001185
#     Cus               (time, sv) float64 7.017e-06 nan nan ... 1.11e-05 1.11e-05
#     sqrtA             (time, sv) float64 5.154e+03 nan ... 5.154e+03 5.154e+03
#     Toe               (time, sv) float64 1.944e+05 nan ... 2.016e+05 2.016e+05
#     Cic               (time, sv) float64 3.818e-07 nan ... -3.353e-08 -3.353e-08
#     Omega0            (time, sv) float64 1.229 nan nan nan ... nan 0.3129 0.3129
#     Cis               (time, sv) float64 2.012e-07 nan ... -5.588e-09 -5.588e-09
#     Io                (time, sv) float64 0.9558 nan nan nan ... nan 0.986 0.986
#     Crc               (time, sv) float64 242.0 nan nan nan ... nan 177.0 177.0
#     omega             (time, sv) float64 -1.714 nan nan nan ... nan 2.006 2.006
#     OmegaDot          (time, sv) float64 -7.969e-09 nan ... -7.596e-09
#     IDOT              (time, sv) float64 3.207e-10 nan ... -1.357e-10 -1.357e-10
#     CodesL2           (time, sv) float64 1.0 nan nan nan nan ... 1.0 nan 1.0 1.0
#     GPSWeek           (time, sv) float64 2.071e+03 nan ... 2.071e+03 2.071e+03
#     L2Pflag           (time, sv) float64 0.0 nan nan nan nan ... 0.0 nan 0.0 0.0
#     SVacc             (time, sv) float64 2.0 nan nan nan nan ... 2.0 nan 2.0 2.0
#     health            (time, sv) float64 0.0 nan nan nan nan ... 0.0 nan 0.0 0.0
#     TGD               (time, sv) float64 -2.049e-08 nan ... -9.779e-09
#     IODC              (time, sv) float64 31.0 nan nan nan ... nan 123.0 123.0
#     TransTime         (time, sv) float64 1.872e+05 nan ... 1.944e+05 1.944e+05
# Attributes:
#     ionospheric_corr_GPS:  [ 7.4506e-09  1.4901e-08 -5.9605e-08 -1.1921e-07  ...
#     version:               3.03
#     svtype:                ['G']
#     rinextype:             nav
#     filename:              ACRD00IND_R_20192600425_02H_GN.rnx
# <bound method Dataset.to_array of <xarray.Dataset>
# Dimensions:           (sv: 12, time: 4)
# Coordinates:
#   * sv                (sv) <U3 'G02' 'G05' 'G10' 'G12' ... 'G26' 'G29' 'G32'
#   * time              (time) datetime64[ns] 2019-09-17T05:59:44 ... 2019-09-17T08:00:00
# Data variables:
#     SVclockBias       (time, sv) float64 -0.0003068 nan ... 9.563e-05 9.563e-05
#     SVclockDrift      (time, sv) float64 -8.185e-12 nan ... -1.023e-11
#     SVclockDriftRate  (time, sv) float64 0.0 nan nan nan nan ... 0.0 nan 0.0 0.0
#     IODE              (time, sv) float64 31.0 nan nan nan ... nan 123.0 123.0
#     Crs               (time, sv) float64 58.0 nan nan nan ... nan -22.72 -22.72
#     DeltaN            (time, sv) float64 4.608e-09 nan ... 3.732e-09 3.732e-09
#     M0                (time, sv) float64 -1.886 nan nan nan ... nan 1.317 1.317
#     Cuc               (time, sv) float64 3.152e-06 nan ... -1.363e-06 -1.363e-06
#     Eccentricity      (time, sv) float64 0.01913 nan nan ... 0.001185 0.001185
#     Cus               (time, sv) float64 7.017e-06 nan nan ... 1.11e-05 1.11e-05
#     sqrtA             (time, sv) float64 5.154e+03 nan ... 5.154e+03 5.154e+03
#     Toe               (time, sv) float64 1.944e+05 nan ... 2.016e+05 2.016e+05
#     Cic               (time, sv) float64 3.818e-07 nan ... -3.353e-08 -3.353e-08
#     Omega0            (time, sv) float64 1.229 nan nan nan ... nan 0.3129 0.3129
#     Cis               (time, sv) float64 2.012e-07 nan ... -5.588e-09 -5.588e-09
#     Io                (time, sv) float64 0.9558 nan nan nan ... nan 0.986 0.986
#     Crc               (time, sv) float64 242.0 nan nan nan ... nan 177.0 177.0
#     omega             (time, sv) float64 -1.714 nan nan nan ... nan 2.006 2.006
#     OmegaDot          (time, sv) float64 -7.969e-09 nan ... -7.596e-09
#     IDOT              (time, sv) float64 3.207e-10 nan ... -1.357e-10 -1.357e-10
#     CodesL2           (time, sv) float64 1.0 nan nan nan nan ... 1.0 nan 1.0 1.0
#     GPSWeek           (time, sv) float64 2.071e+03 nan ... 2.071e+03 2.071e+03
#     L2Pflag           (time, sv) float64 0.0 nan nan nan nan ... 0.0 nan 0.0 0.0
#     SVacc             (time, sv) float64 2.0 nan nan nan nan ... 2.0 nan 2.0 2.0
#     health            (time, sv) float64 0.0 nan nan nan nan ... 0.0 nan 0.0 0.0
#     TGD               (time, sv) float64 -2.049e-08 nan ... -9.779e-09
#     IODC              (time, sv) float64 31.0 nan nan nan ... nan 123.0 123.0
#     TransTime         (time, sv) float64 1.872e+05 nan ... 1.944e+05 1.944e+05
# Attributes:
#     ionospheric_corr_GPS:  [ 7.4506e-09  1.4901e-08 -5.9605e-08 -1.1921e-07  ...
#     version:               3.03
#     svtype:                ['G']
#     rinextype:             nav
#     filename:              ACRD00IND_R_20192600425_02H_GN.rnx>
#                          SVclockBias  SVclockDrift  ...   IODC  TransTime
# sv  time                                            ...
# G02 2019-09-17 05:59:44    -0.000307 -8.185452e-12  ...   31.0   187184.0
#     2019-09-17 08:00:00    -0.000307 -8.185452e-12  ...   54.0   194400.0
# G05 2019-09-17 06:00:00    -0.000001 -3.410605e-13  ...   65.0   187200.0
#     2019-09-17 08:00:00    -0.000001 -3.410605e-13  ...   67.0   194400.0
# G10 2019-09-17 06:00:00    -0.000057 -1.534772e-11  ...   68.0   187200.0
#     2019-09-17 08:00:00    -0.000057 -1.534772e-11  ...   70.0   194400.0
# G12 2019-09-17 06:00:00     0.000203 -3.751666e-12  ...   54.0   187200.0
#     2019-09-17 08:00:00     0.000203 -3.751666e-12  ...   82.0   194400.0
# G13 2019-09-17 06:00:00    -0.000044  2.046363e-12  ...   70.0   187200.0
#     2019-09-17 08:00:00    -0.000044  2.046363e-12  ...   75.0   194400.0
# G15 2019-09-17 06:00:00    -0.000286  2.728484e-12  ...   68.0   187200.0
#     2019-09-17 08:00:00    -0.000286  2.728484e-12  ...   72.0   194400.0
# G20 2019-09-17 06:00:00     0.000527  1.136868e-13  ...   25.0   187200.0
#     2019-09-17 08:00:00     0.000527  1.136868e-13  ...   73.0   194400.0
# G21 2019-09-17 06:00:00    -0.000118  6.480150e-12  ...   33.0   187200.0
#     2019-09-17 08:00:00    -0.000117  6.480150e-12  ...   35.0   194400.0
# G25 2019-09-17 06:00:00    -0.000012 -1.477929e-12  ...   91.0   187200.0
#     2019-09-17 08:00:00    -0.000012 -1.477929e-12  ...   92.0   194400.0
# G26 2019-09-17 07:59:44     0.000041  8.753887e-12  ...    1.0   194384.0
# G29 2019-09-17 06:00:00     0.000096 -1.023182e-11  ...  122.0   187200.0
#     2019-09-17 08:00:00     0.000096 -1.023182e-11  ...  123.0   194400.0
# G32 2019-09-17 06:00:00     0.000096 -1.023182e-11  ...  122.0   187200.0
#     2019-09-17 08:00:00     0.000096 -1.023182e-11  ...  123.0   194400.0
#
# [23 rows x 28 columns]
